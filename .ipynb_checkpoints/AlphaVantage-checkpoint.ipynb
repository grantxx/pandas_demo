# %%
from alpha_vantage.foreignexchange import ForeignExchange
import matplotlib.pyplot as plt
cc = ForeignExchange(key='OGRPFV5D58LC77OL',output_format='pandas')
import pandas as pd
from datetime import datetime
# get_currency_exchange_intraday()
# get_currency_exchange_daily()
# get_currency_exchange_weekly()
# get_currency_exchange_monthly()
#data_daily, meta_data = cc.get_currency_exchange_daily(from_symbol='EUR',to_symbol='USD', outputsize='full')
data_60m, meta_data = cc.get_currency_exchange_intraday(from_symbol='EUR',to_symbol='USD',interval='60min', outputsize='full')

# %%
def cleanup_column(df):    
    df.columns = ['open','high','low','close'] #Make sure column names are legit    
    df.reset_index(inplace=True) #reset the fuclin index    
    return df

cleanup_column(data_60m)
data_60m.reset_index(inplace=True)
data_60m = data_60m.loc[(data_60m['date'] > '2020-01-10 14:00:00')]

# %%
print(data_60m.columns)
# Out:
# Index(['index', 'date', 'open', 'high', 'low', 'close'], dtype='object')

# %%
fig = plt.figure(figsize=(12,10))
fig.subplots_adjust(hspace=0.3)

# Divide the figure into a 2x1 grid, and give me the first section
ax1 = fig.add_subplot(211)

# Divide the figure into a 2x1 grid, and give me the second section
ax2 = fig.add_subplot(212)
data_60m.plot(x='date', y='open', ax=ax1, legend=False)
data_60m.plot.scatter(x='index', y='open', ax=ax2)
ax2.yaxis.set_label_text("")
ax2.invert_xaxis()
ax2.set_ylim([1.110,1.115])
ax2.set_title('60 min Open Prices')
# Out:
# Text(0.5, 1.0, '60 min Open Prices')

# %%
df = data_60m.copy()
df.sort_values(by=['index'],inplace=True,ascending=False)

# %%
#f = data_60m_copy[(data_60m_copy.date.dt.weekday == 0) & (data_60m_copy.date.dt.weekday == 1)]
df1 = df[df.date.dt.weekday == 0]
df2 = df[df.date.dt.weekday == 1]
df3 = df[df.date.dt.weekday == 2]
df4 = df[df.date.dt.weekday == 3]
df5 = df[df.date.dt.weekday == 4]
#data_60m_copy.plot(x='date',y='open')
print(df1.head(50))
print(df2.head(50))
print(df3.head(50))
print(df4.head(50))
print(df5.head(50))
# Out:
#     index                date    open    high     low   close Day of Week
# 91     91 2020-01-13 00:00:00  1.1116  1.1119  1.1114  1.1118      Monday
# 90     90 2020-01-13 01:00:00  1.1119  1.1121  1.1116  1.1121      Monday
# 89     89 2020-01-13 02:00:00  1.1120  1.1126  1.1118  1.1126      Monday
# 88     88 2020-01-13 03:00:00  1.1126  1.1130  1.1124  1.1129      Monday
# 87     87 2020-01-13 04:00:00  1.1129  1.1131  1.1126  1.1127      Monday
# 86     86 2020-01-13 05:00:00  1.1126  1.1132  1.1125  1.1129      Monday
# 85     85 2020-01-13 06:00:00  1.1130  1.1130  1.1123  1.1129      Monday
# 84     84 2020-01-13 07:00:00  1.1129  1.1130  1.1120  1.1123      Monday
# 83     83 2020-01-13 08:00:00  1.1123  1.1130  1.1119  1.1128      Monday
# 82     82 2020-01-13 09:00:00  1.1128  1.1136  1.1113  1.1115      Monday
# 81     81 2020-01-13 10:00:00  1.1115  1.1120  1.1111  1.1117      Monday
# 80     80 2020-01-13 11:00:00  1.1117  1.1124  1.1115  1.1120      Monday
# ...

# %%
df['Day of Week'] = df['date'].dt.day_name()

new_df = df.loc[(df['Day of Week'] == 'Monday') & (df['Day of Week'] == 'Tuesday')]
print(df.count())
# Out:
# index          149
# date           149
# open           149
# high           149
# low            149
# close          149
# Day of Week    149
# dtype: int64
